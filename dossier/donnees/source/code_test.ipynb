# %%
import pandas as pd

# %%
df = pd.read_csv("en openfoodfacts org products.csv")

# %%
df.drop(df[df['pnns_groups_1'] == "unknown"].index, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4735 entries, 6971 to 13218
# Data columns (total 18 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   code                                     4735 non-null   int64
#  1   product_name                             4475 non-null   object
#  2   quantity                                 3582 non-null   object
#  3   packaging_en                             1798 non-null   object
#  4   brands_en                                4488 non-null   object
#  5   categories_en                            4653 non-null   object
#  6   origins_en                               888 non-null    object
#  7   labels_en                                2494 non-null   object
#  8   countries_en                             4735 non-null   object
#  9   nutriscore_grade                         4650 non-null   object
#  10  pnns_groups_1                            4650 non-null   object
#  11  pnns_groups_2                            4650 non-null   object
#  12  food_groups_en                           4650 non-null   object
#  13  environmental_score_score                937 non-null    float64
#  14  environmental_score_grade                1389 non-null   object
#  15  main_category_en                         4653 non-null   object
#  16  carbon-footprint_100g                    2 non-null      float64
#  17  carbon-footprint-from-meat-or-fish_100g  5 non-null      float64
# dtypes: float64(3), int64(1), object(14)
# memory usage: 702.9+ KB

# %%
df.dropna(subset=['pnns_groups_2'], inplace=True)

# %%
df.to_csv("cleaned_data.csv")

# %%
df_co2 = pd.read_csv('https://raw.githubusercontent.com/Phi-project3/finalproject/refs/heads/main/dossier/donnees/source/category_schema/products_category_schema_v1.csv', sep=';')

df_co2.dropna(subset=['category_name'], inplace=True)

df_merged = df.merge(df_co2[['category_name', 'average']], how='left', left_on='pnns_groups_2', right_on='category_name')

df_merged.drop(columns=['category_name', 'carbon-footprint_100g', 'carbon-footprint-from-meat-or-fish_100g'], inplace=True)

df_merged.rename(columns={'average': 'carbon-footprint_1kg'}, inplace=True)

df_merged.sample(5)
# Out:
#                code               product_name  quantity  \
# 2872       20072803             Miel de fleurs      500g
# 4144  6412500003445   Panda Tekee Hyvää suklaa     200 g
# 130   4056489927129          Mozzarella grated     250 g
# 660   6408430408641  Arki jogurtti maustamaton      1 kg
# 1073  8714100868867                        NaN  0.073 kg
#
#                                            packaging_en    brands_en  \
# 2872  Plastic,Pet-polyethylene-terephthalate,Pp-poly...      Maribel
# 4144                           Plastic,Pp-polypropylene  Panda,Orkla
# 130                                                 NaN      milbona
# 660                                                 NaN        Valio
# 1073                                                NaN        Knorr
#
#                                           categories_en  \
# 2872  Breakfasts,Spreads,Sweet spreads,Bee products,...
# 4144  Snacks,Sweet snacks,Cocoa and its products,Con...
# 130   Dairies,Fermented foods,Fermented milk product...
# 660   Dairies,Fermented foods,Fermented milk product...
# 1073     Meals,Savory semolina dishes,Prepared couscous
#
#                                origins_en                        labels_en  \
# 2872  Spain,Argentina,Cuba,Mexico,Romania                        Green Dot
# 4144                                  NaN  No palm oil,Rainforest Alliance
# 130                                   NaN                              NaN
# 660                                   NaN                              NaN
# 1073                                  NaN                              NaN
#
#                        countries_en nutriscore_grade            pnns_groups_1  \
# 2872  Finland,France,Germany,Sweden                d            Sugary snacks
# 4144                        Finland                e            Sugary snacks
# 130        Bulgaria,Finland,Romania                d  Milk and dairy products
# 660                         Finland                b  Milk and dairy products
# 1073                        Finland          unknown          Composite foods
#
#         pnns_groups_2                           food_groups_en  \
# 2872           Sweets                     Sugary snacks,Sweets
# 4144           Sweets                     Sugary snacks,Sweets
# 130            Cheese           Milk and dairy products,Cheese
# 660   Milk and yogurt  Milk and dairy products,Milk and yogurt
# 1073   One-dish meals           Composite foods,One-dish meals
#
#       environmental_score_score environmental_score_grade   main_category_en  \
# 2872                       78.0                         a      Liquid honeys
# 4144                        NaN                       NaN            Bonbons
# 130                        55.0                         c                  A
# 660                         NaN                       NaN            Yogurts
# 1073                        NaN                       NaN  Prepared couscous
#
#       carbon-footprint_1kg
# 2872                  2.95
# 4144                  2.95
# 130                  12.05
# 660                   1.05
# 1073                  2.95

# %%
df_merged.to_csv("merged_data.csv")
# Out:
# (4650, 17)
