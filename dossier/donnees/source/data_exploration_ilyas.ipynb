# %%
import pandas as pd 

df = pd.read_csv('en openfoodfacts org products.csv')

# %%
df.head(5)
# Out:
#            code product_name quantity packaging_en brands_en categories_en  \
# 0     301762042          NaN      NaN          NaN       NaN           NaN
# 1    2045652893          NaN      NaN          NaN       NaN           NaN
# 2    3017620422          NaN      NaN          NaN       NaN           NaN
# 3  490000030464          NaN      NaN          NaN       NaN           NaN
# 4      11702334          NaN      NaN          NaN       NaN           NaN
#
#   origins_en labels_en countries_en nutriscore_grade pnns_groups_1  \
# 0        NaN       NaN      Finland          unknown       unknown
# 1        NaN       NaN      Finland          unknown       unknown
# 2        NaN       NaN      Finland          unknown       unknown
# 3        NaN       NaN      Finland          unknown       unknown
# 4        NaN       NaN      Finland          unknown       unknown
#
#   pnns_groups_2 food_groups_en  environmental_score_score  \
# 0       unknown            NaN                        NaN
# 1       unknown            NaN                        NaN
# 2       unknown            NaN                        NaN
# 3       unknown            NaN                        NaN
# 4       unknown            NaN                        NaN
#
#   environmental_score_grade main_category_en  carbon-footprint_100g  \
# 0                       NaN              NaN                    NaN
# 1                       NaN              NaN                    NaN
# 2                       NaN              NaN                    NaN
# 3                       NaN              NaN                    NaN
# 4                       NaN              NaN                    NaN
#
#    carbon-footprint-from-meat-or-fish_100g
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN

# %%
df['pnns_groups_2'].value_counts()
# Out:
# pnns_groups_2
# unknown                             8484
# Sweets                               510
# Biscuits and cakes                   382
# Milk and yogurt                      363
# One-dish meals                       283
# Dairy desserts                       279
# Bread                                251
# Cheese                               194
# Dressings and sauces                 189
# Breakfast cereals                    185
# Chocolate products                   176
# Meat                                 169
# Cereals                              162
# Sweetened beverages                  148
# Ice cream                            131
# Processed meat                       128
# Plant-based milk substitutes         113
# Vegetables                            92
# Artificially sweetened beverages      83
# Alcoholic beverages                   80
# Unsweetened beverages                 69
# Fats                                  68
# Fish and seafood                      65
# Appetizers                            64
# Salty and fatty products              61
# Pizza pies and quiches                59
# Fruits                                53
# Legumes                               46
# Fruit juices                          42
# Nuts                                  36
# Eggs                                  31
# Potatoes                              28
# Waters and flavored waters            25
# Sandwiches                            24
# Soups                                 24
# Dried fruits                          20
# Teas and herbal teas and coffees      12
# Pastries                               4
# Fruit nectars                          1
# Name: count, dtype: int64

# %%
df_category = df['main_category_en'].value_counts()

df_category.to_csv('test.csv')

# %%
df['pnns_groups_1'].value_counts()
# Out:
# pnns_groups_1
# unknown                    8484
# Sugary snacks              1072
# Milk and dairy products     967
# Cereals and potatoes        672
# Beverages                   493
# Fish Meat Eggs              393
# Composite foods             366
# Fat and sauces              257
# Fruits and vegetables       189
# Salty snacks                161
# Alcoholic beverages          80
# Name: count, dtype: int64

# %%
dividing = df['pnns_groups_2'].value_counts()

dividing.to_csv('future_dividing.csv')

# %%
df['pnns_groups_1'].value_counts()
# Out:
# pnns_groups_1
# unknown                    8484
# Sugary snacks              1072
# Milk and dairy products     967
# Cereals and potatoes        672
# Beverages                   493
# Fish Meat Eggs              393
# Composite foods             366
# Fat and sauces              257
# Fruits and vegetables       189
# Salty snacks                161
# Alcoholic beverages          80
# Name: count, dtype: int64

# %%
sample = df[df['pnns_groups_2'] == 'Milk and yogurt']

sample.to_csv('sample.csv')

# %%
df[df['pnns_groups_2'] == 'Fruit nectars'].sample(1)
# Out:
#                code                       product_name quantity packaging_en  \
# 8574  6470910139680  Nectar multifruits - €.C.O.+ - 2L  2000.0g          NaN
#
#      brands_en                                      categories_en origins_en  \
# 8574       C-o  Plant-based foods and beverages,Beverages,Plan...        NaN
#
#      labels_en countries_en nutriscore_grade pnns_groups_1  pnns_groups_2  \
# 8574       NaN      Finland          unknown     Beverages  Fruit nectars
#
#                food_groups_en  environmental_score_score  \
# 8574  Beverages,Fruit nectars                        NaN
#
#      environmental_score_grade    main_category_en  carbon-footprint_100g  \
# 8574                       NaN  Multifruit nectars                    NaN
#
#       carbon-footprint-from-meat-or-fish_100g
# 8574                                      NaN

# %% [markdown]
# IF pnns_groups_2 == 'Milk and yogurt':
#     IF categories_en IN 'Yogurt':
#         carbon-footprint_100g = 1.5
#     ELIF categories_en IN 'Tea' AND packaging_en IN 'Paperboard':
#         carbon-footprint_100g = 2
#     ELIF categories_en IN 'Tea' AND packaging_en IN 'Plastic':
#         carbon-footprint_100g = 10
#     ELSE:
#         carbon-footprint_100g = 2

# %% [markdown]
# IF pnns_groups_2 == 'Milk and yogurt':
#         carbon-footprint_100g = 2

# %%
df_sweet = df[df['pnns_groups_2'] == 'Sweets']

df_sweet.shape
# Out:
# (510, 18)

# %%
# df.loc[df['pnns_groups_2'] == 'Sweets', 'carbon-footprint_100g'] = 2.95


# df.loc[df['pnns_groups_2'] == 'Sweets', 'carbon-footprint_100g'] = 2

df.drop(df[df['pnns_groups_1'] == "unknown"].index, inplace=True)
df.dropna(subset=['pnns_groups_1'], inplace=True)

df.shape
# Out:
# (4650, 18)

# %%
df_co2 = pd.read_csv('https://raw.githubusercontent.com/Phi-project3/finalproject/refs/heads/main/dossier/donnees/source/category_schema/products_category_schema_v1.csv', sep=';')

df_co2.sample(5)
# Out:
#                    source_product_category                     category_name  \
# 14                                 Yogurts                               NaN
# 64                             Cut flowers                               NaN
# 4            Soft drinks and energy drinks  Artificially sweetened beverages
# 34  Ready-made meals and convenience foods                             Soups
# 41      Wild-caught domestic fish, average                               NaN
#
#     kg_CO2_min  kg_CO2_max  average
# 14         1.1         1.7     1.40
# 64         0.4         8.5     4.45
# 4          0.1         1.0     0.55
# 34         1.2         4.7     2.95
# 41         0.4         2.7     1.55

# %%
df_merged = df.merge(df_co2[['category_name', 'average']], how='left', left_on='pnns_groups_2', right_on='category_name')

df_merged.drop(columns=['category_name', 'carbon-footprint_100g', 'carbon-footprint-from-meat-or-fish_100g'], inplace=True)

df_merged.rename(columns={'average': 'carbon-footprint_100g'}, inplace=True)

df_merged.sample(5)
# Out:
#                code                         product_name quantity  \
# 3273  8436048962697                     Filipinos Blanco    128 g
# 2042  6416419130988                   Jalotofu marinoitu     300g
# 4465  6410405178053               Laktoositon mozzarella    125 g
# 760   6410405293961                          Hyviskeitto    300 g
# 1143  5706911004124  Chicken Red Curry with Jasmine Rice      NaN
#
#           packaging_en          brands_en  \
# 3273  Plastic,Bag,Tray  artiach,filipinos
# 2042               NaN           Jalotofu
# 4465  Plastic,fi:pa-pe             Pirkka
# 760                NaN              Kesko
# 1143               NaN        Nice-n-easy
#
#                                           categories_en origins_en  \
# 3273  Snacks,Sweet snacks,Biscuits and cakes,Biscuit...        NaN
# 2042  Plant-based foods and beverages,Plant-based fo...        NaN
# 4465  Dairies,Fermented foods,Fermented milk product...        NaN
# 760                                         Meals,Soups        NaN
# 1143  Meats and their products,Meals,Meats,Chicken a...        NaN
#
#                                               labels_en  \
# 3273                                          Green Dot
# 2042  No gluten,Organic,EU Organic,FI-EKO-201,Fi-043...
# 4465                                                NaN
# 760                                                 NaN
# 1143                                                NaN
#
#                       countries_en nutriscore_grade            pnns_groups_1  \
# 3273  Finland,France,Morocco,Spain                e            Sugary snacks
# 2042                       Finland                b     Cereals and potatoes
# 4465                       Finland                c  Milk and dairy products
# 760                        Finland                c          Composite foods
# 1143                       Finland                c           Fish Meat Eggs
#
#            pnns_groups_2                    food_groups_en  \
# 3273  Biscuits and cakes  Sugary snacks,Biscuits and cakes
# 2042             Legumes      Cereals and potatoes,Legumes
# 4465              Cheese    Milk and dairy products,Cheese
# 760       One-dish meals    Composite foods,One-dish meals
# 1143                Meat     Fish‚ Meat‚ Eggs,Meat,Poultry
#
#       environmental_score_score environmental_score_grade  \
# 3273                       27.0                         e
# 2042                        NaN                       NaN
# 4465                        NaN                       NaN
# 760                         NaN                       NaN
# 1143                        NaN                       NaN
#
#               main_category_en  carbon-footprint_100g
# 3273  White chocolate biscuits                   2.50
# 2042                      Tofu                   1.55
# 4465                Mozzarella                  12.05
# 760                      Soups                   2.95
# 1143             Chicken curry                  43.33

# %%
# df[df['pnns_groups_2'] == 'Soups']

df[df['code'] == 20043032]
# Out:
#           code    product_name quantity packaging_en   brands_en  \
# 7413  20043032  Easter Egg Mix      NaN          NaN  Fresh-easy
#
#      categories_en origins_en labels_en           countries_en  \
# 7413   Meals,Soups        NaN       NaN  Finland,United States
#
#      nutriscore_grade    pnns_groups_1   pnns_groups_2  \
# 7413                e  Composite foods  One-dish meals
#
#                       food_groups_en  environmental_score_score  \
# 7413  Composite foods,One-dish meals                        NaN
#
#      environmental_score_grade main_category_en  carbon-footprint_100g  \
# 7413                       NaN            Soups                    NaN
#
#       carbon-footprint-from-meat-or-fish_100g
# 7413                                      NaN
