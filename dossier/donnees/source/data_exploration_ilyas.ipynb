# %%
import pandas as pd 

df = pd.read_csv('en openfoodfacts org products.csv')

# %%
df.head(5)
# Out:
#            code product_name quantity packaging_en brands_en categories_en  \
# 0     301762042          NaN      NaN          NaN       NaN           NaN
# 1    2045652893          NaN      NaN          NaN       NaN           NaN
# 2    3017620422          NaN      NaN          NaN       NaN           NaN
# 3  490000030464          NaN      NaN          NaN       NaN           NaN
# 4      11702334          NaN      NaN          NaN       NaN           NaN
#
#   origins_en labels_en countries_en nutriscore_grade pnns_groups_1  \
# 0        NaN       NaN      Finland          unknown       unknown
# 1        NaN       NaN      Finland          unknown       unknown
# 2        NaN       NaN      Finland          unknown       unknown
# 3        NaN       NaN      Finland          unknown       unknown
# 4        NaN       NaN      Finland          unknown       unknown
#
#   pnns_groups_2 food_groups_en  environmental_score_score  \
# 0       unknown            NaN                        NaN
# 1       unknown            NaN                        NaN
# 2       unknown            NaN                        NaN
# 3       unknown            NaN                        NaN
# 4       unknown            NaN                        NaN
#
#   environmental_score_grade main_category_en  carbon-footprint_100g  \
# 0                       NaN              NaN                    NaN
# 1                       NaN              NaN                    NaN
# 2                       NaN              NaN                    NaN
# 3                       NaN              NaN                    NaN
# 4                       NaN              NaN                    NaN
#
#    carbon-footprint-from-meat-or-fish_100g
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN

# %%
df['pnns_groups_2'].value_counts()
# Out:
# pnns_groups_2
# unknown                             8484
# Sweets                               510
# Biscuits and cakes                   382
# Milk and yogurt                      363
# One-dish meals                       283
# Dairy desserts                       279
# Bread                                251
# Cheese                               194
# Dressings and sauces                 189
# Breakfast cereals                    185
# Chocolate products                   176
# Meat                                 169
# Cereals                              162
# Sweetened beverages                  148
# Ice cream                            131
# Processed meat                       128
# Plant-based milk substitutes         113
# Vegetables                            92
# Artificially sweetened beverages      83
# Alcoholic beverages                   80
# Unsweetened beverages                 69
# Fats                                  68
# Fish and seafood                      65
# Appetizers                            64
# Salty and fatty products              61
# Pizza pies and quiches                59
# Fruits                                53
# Legumes                               46
# Fruit juices                          42
# Nuts                                  36
# Eggs                                  31
# Potatoes                              28
# Waters and flavored waters            25
# Sandwiches                            24
# Soups                                 24
# Dried fruits                          20
# Teas and herbal teas and coffees      12
# Pastries                               4
# Fruit nectars                          1
# Name: count, dtype: int64

# %%
df_category = df['main_category_en'].value_counts()

df_category.to_csv('test.csv')

# %%
df['pnns_groups_1'].value_counts()
# Out:
# pnns_groups_1
# unknown                    8484
# Sugary snacks              1072
# Milk and dairy products     967
# Cereals and potatoes        672
# Beverages                   493
# Fish Meat Eggs              393
# Composite foods             366
# Fat and sauces              257
# Fruits and vegetables       189
# Salty snacks                161
# Alcoholic beverages          80
# Name: count, dtype: int64

# %%
dividing = df['pnns_groups_2'].value_counts()

dividing.to_csv('future_dividing.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[12], line 3
#       1 dividing = df['pnns_groups_2'].value_counts()
# ----> 3 dividing.to_csv('future_dividing.csv')
#
# File c:\code\repos\finalproject\.venv\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\code\repos\finalproject\.venv\Lib\site-packages\pandas\core\generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)   3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File c:\code\repos\finalproject\.venv\Lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)   1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File c:\code\repos\finalproject\.venv\Lib\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)    267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File c:\code\repos\finalproject\.venv\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: 'future_dividing.csv'

# %%
df['pnns_groups_1'].value_counts()
# Out:
# pnns_groups_1
# Sugary snacks              1072
# Milk and dairy products     967
# Cereals and potatoes        672
# Beverages                   493
# Fish Meat Eggs              393
# Composite foods             366
# Fat and sauces              257
# Fruits and vegetables       189
# Salty snacks                161
# Alcoholic beverages          80
# Name: count, dtype: int64

# %%
sample = df[df['pnns_groups_2'] == 'Milk and yogurt']

sample.to_csv('sample.csv')

# %%
df[df['pnns_groups_2'] == 'Fruit nectars'].sample(1)
# Out:
#                code                       product_name quantity packaging_en  \
# 8574  6470910139680  Nectar multifruits - €.C.O.+ - 2L  2000.0g          NaN
#
#      brands_en                                      categories_en origins_en  \
# 8574       C-o  Plant-based foods and beverages,Beverages,Plan...        NaN
#
#      labels_en countries_en nutriscore_grade pnns_groups_1  pnns_groups_2  \
# 8574       NaN      Finland          unknown     Beverages  Fruit nectars
#
#                food_groups_en  environmental_score_score  \
# 8574  Beverages,Fruit nectars                        NaN
#
#      environmental_score_grade    main_category_en  carbon-footprint_100g  \
# 8574                       NaN  Multifruit nectars                    NaN
#
#       carbon-footprint-from-meat-or-fish_100g
# 8574                                      NaN

# %%
IF pnns_groups_2 == 'Milk and yogurt':
    IF categories_en IN 'Yogurt':
        carbon-footprint_100g = 1.5
    ELIF categories_en IN 'Tea' AND packaging_en IN 'Paperboard':
        carbon-footprint_100g = 2
    ELIF categories_en IN 'Tea' AND packaging_en IN 'Plastic':
        carbon-footprint_100g = 10
    ELSE:
        carbon-footprint_100g = 2

# %% [markdown]
# IF pnns_groups_2 == 'Milk and yogurt':
#         carbon-footprint_100g = 2

# %%
df_sweet = df[df['pnns_groups_2'] == 'Sweets']

df_sweet.shape
# Out:
# (510, 18)

# %%
df.loc[df['pnns_groups_2'] == 'Sweets', 'carbon-footprint_100g'] = 2.95


df.loc[df['pnns_groups_2'] == 'Sweets', 'carbon-footprint_100g'] = 2
# Out:
#                 code         product_name quantity  \
# 12088  6410220009006      Oat snack mango      NaN
# 8232   6410405197658               Hunaja    500 g
# 7469   6411401037153  Pax original recipe      NaN
# 10253   704039020496       Scottish Fudge     250g
# 11547  5411188128601         Skyr Vanille   0.4 kg
#
#                                             packaging_en        brands_en  \
# 12088  Metal,Plastic,Recyclable Metals,Aluminium,Cont...  Fazer-norway-as
# 8232                                                 NaN           Pirkka
# 7469                                                 NaN            Fazer
# 10253                                                NaN       The-broons
# 11547    Metal,Pot,Recyclable Metals,Aluminium,Plastique        Danone-as
#
#                                            categories_en origins_en  \
# 12088  Plant-based foods and beverages,Fermented food...    Finland
# 8232   Breakfasts,Spreads,Sweet spreads,Bee products,...        NaN
# 7469   Snacks,Sweet snacks,Cocoa and its products,Con...        NaN
# 10253       Snacks,Sweet snacks,Confectioneries,Caramels        NaN
# 11547  Plant-based foods and beverages,Dairies,Fermen...        NaN
#
#        labels_en                        countries_en nutriscore_grade  \
# 12088  No gluten                             Finland                b
# 8232         NaN                             Finland          unknown
# 7469         NaN                      Finland,France                d
# 10253  Green Dot                             Finland          unknown
# 11547  No gluten  Finland,France,Germany,Switzerland                a
#
#        pnns_groups_1 pnns_groups_2        food_groups_en  \
# 12088  Sugary snacks        Sweets  Sugary snacks,Sweets
# 8232   Sugary snacks        Sweets  Sugary snacks,Sweets
# 7469   Sugary snacks        Sweets  Sugary snacks,Sweets
# 10253  Sugary snacks        Sweets  Sugary snacks,Sweets
# 11547  Sugary snacks        Sweets  Sugary snacks,Sweets
#
#        environmental_score_score environmental_score_grade  main_category_en  \
# 12088                        NaN                       NaN  Oat milk yogurts
# 8232                         NaN                       NaN            Honeys
# 7469                         NaN                   unknown           Bonbons
# 10253                        NaN                       NaN          Caramels
# 11547                       80.0                         a  Soy milk yogurts
#
#        carbon-footprint_100g  carbon-footprint-from-meat-or-fish_100g
# 12088                    2.0                                      NaN
# 8232                     2.0                                      NaN
# 7469                     2.0                                      NaN
# 10253                    2.0                                      NaN
# 11547                    2.0                                      NaN

# %%
df_test = pd.read_csv('intermediate.csv', sep=';')

df_test.sample(5)
# Out:
#               source_product_category       category_name  kg_CO2_min  \
# 52                   Chips and snacks          Appetizers         1.7
# 21             Tomatoes and cucumbers                 NaN         0.1
# 44  Salmon and trout, foreign, farmed                 NaN         4.1
# 49      Bread, biscuits, and pastries  Biscuits and cakes         0.5
# 10                               Milk     Milk and yogurt         0.9
#
#     kg_CO2_max  average
# 52         2.5     2.10
# 21         3.0     1.55
# 44         6.7     5.40
# 49         4.5     2.50
# 10         1.2     1.05
